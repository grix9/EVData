# %% [markdown]
# Electric Vehicle Data Washinton USA, 2020-2025

# %%
import pandas as pd
import matplotlib.pyplot as plt

evdf = pd.read_csv('Electric_Vehicle_population_data.csv')
print(evdf.head(1))
# Out:
#    VIN (1-10)  County    City State  Postal Code  Model Year  Make Model  \
# 0  3C3CFFGE1G  Yakima  Yakima    WA      98908.0        2016  FIAT   500
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible            84.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                  14.0       180778377
#
#               Vehicle Location Electric Utility  2020 Census Tract
# 0  POINT (-120.60199 46.59817)       PACIFICORP       5.307700e+10

# %%
# Top 10 Most Popular EV Brands Pie Chart, Top 5 Make and Model

top_evs_brands = evdf['Make'].value_counts()
evdf['Make'].value_counts().head(10).plot.pie()

tops_models = evdf['Model'].value_counts()
#print(tops_models)

# %%
# MSRP Statistics
# Average MSRP, Brand with Highest MSRP, MSRP and Range Correlation Scatter Plot, Top Range, Average Range

#plt.scatter(x=evdf['Electric Range'], y=evdf['Base MSRP'])
print(evdf['Electric Range'].mean())
print(evdf['Base MSRP'].unique())
# Out:
# 40.75169188894534
# [     0.  45600.  69900.  36900.  31950. 110950.  81100.  39995.  34995.
#   32250.  36800.  52900.  54950.  90700.  55700.  53400.  33950.  44100.
#   98950.  64950. 184400.  59900.  89100.  43700. 109000.  52650.     nan
#  102000.  75095.  32995. 845000.  91250.]

# %%
# Most Popular Year, Post Code with Most EVs
